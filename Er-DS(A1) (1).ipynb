# %%
import pandas as pd 
import statistics as stats 
import scipy.stats as st 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Q7

# %%
df = pd.read_csv("C:/Users/Shivani Bhavsar/OneDrive/Documents/ExcelR Assignment files/Q7.csv", index_col=0)
df
# Out:
#                      Points  Score  Weigh
# Mazda RX4              3.90  2.620  16.46
# Mazda RX4 Wag          3.90  2.875  17.02
# Datsun 710             3.85  2.320  18.61
# Hornet 4 Drive         3.08  3.215  19.44
# Hornet Sportabout      3.15  3.440  17.02
# Valiant                2.76  3.460  20.22
# Duster 360             3.21  3.570  15.84
# Merc 240D              3.69  3.190  20.00
# Merc 230               3.92  3.150  22.90
# Merc 280               3.92  3.440  18.30
# Merc 280C              3.92  3.440  18.90
# Merc 450SE             3.07  4.070  17.40
# Merc 450SL             3.07  3.730  17.60
# Merc 450SLC            3.07  3.780  18.00
# Cadillac Fleetwood     2.93  5.250  17.98
# Lincoln Continental    3.00  5.424  17.82
# Chrysler Imperial      3.23  5.345  17.42
# Fiat 128               4.08  2.200  19.47
# Honda Civic            4.93  1.615  18.52
# Toyota Corolla         4.22  1.835  19.90
# Toyota Corona          3.70  2.465  20.01
# ...

# %%
df.agg(["mean","var","std","min","max","median"])
# Out:
#           Points     Score      Weigh
# mean    3.596563  3.217250  17.848750
# var     0.285881  0.957379   3.193166
# std     0.534679  0.978457   1.786943
# min     2.760000  1.513000  14.500000
# max     4.930000  5.424000  22.900000
# median  3.695000  3.325000  17.710000

# %%
df.mode()
# Out:
#    Points  Score  Weigh
# 0    3.07   3.44  17.02
# 1    3.92    NaN  18.90

# %%
df["Points"]. value_counts()
# Out:
# 3.92    3
# 3.07    3
# 3.90    2
# 4.22    2
# 3.08    2
# 3.15    2
# 2.76    2
# 4.08    2
# 3.54    1
# 3.62    1
# 3.77    1
# 4.43    1
# 3.73    1
# 3.70    1
# 3.23    1
# 4.93    1
# 3.85    1
# 3.00    1
# 2.93    1
# 3.69    1
# 3.21    1
# 4.11    1
# Name: Points, dtype: int64

# %%
range = (df.max()-df.min())
range
# Out:
# Points    2.170
# Score     3.911
# Weigh     8.400
# dtype: float64

# %% [markdown]
# # Q9

# %%
df1=pd.read_csv("C:/Users/Shivani Bhavsar/OneDrive/Documents/ExcelR Assignment files/Q9_a.csv", index_col=0)
df1
# Out:
#        speed  dist
# Index
# 1          4     2
# 2          4    10
# 3          7     4
# 4          7    22
# 5          8    16
# 6          9    10
# 7         10    18
# 8         10    26
# 9         10    34
# 10        11    17
# 11        11    28
# 12        12    14
# 13        12    20
# 14        12    24
# 15        12    28
# 16        13    26
# 17        13    34
# 18        13    34
# 19        13    46
# 20        14    26
# 21        14    36
# 22        14    60
# 23        14    80
# 24        15    20
# 25        15    26
# 26        15    54
# 27        16    32
# 28        16    40
# 29        17    32
# 30        17    40
# 31        17    50
# 32        18    42
# 33        18    56
# 34        18    76
# 35        18    84
# 36        19    36
# 37        19    46
# 38        19    68
# 39        20    32
# 40        20    48
# 41        20    52
# 42        20    56
# 43        20    64
# 44        22    66
# 45        23    54
# 46        24    70
# ...

# %%
df1.agg(["skew","kurt"])
# Out:
#          speed      dist
# skew -0.117510  0.806895
# kurt -0.508994  0.405053

# %% [markdown]
# # Q9_b

# %%
df2 = pd.read_csv("C:/Users/Shivani Bhavsar/OneDrive/Documents/ExcelR Assignment files/Q9_b.csv",index_col=0)

# %%
df2.agg(["skew","kurt"])
# Out:
#             SP        WT
# skew  1.611450 -0.614753
# kurt  2.977329  0.950291

# %% [markdown]
# # Q12

# %%
df12 = ([34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56])
df12
# Out:
# [34, 36, 36, 38, 38, 39, 39, 40, 40, 41, 41, 41, 41, 42, 42, 45, 49, 56]

# %%
stats.mean(df12),stats.median(df12),stats.variance(df12),stats.stdev(df12)
# Out:
# (41, 40.5, 25.529411764705884, 5.05266382858645)

# %% [markdown]
# # Q20

# %%
df20 =pd.read_csv("C:/Users/Shivani Bhavsar/OneDrive/Documents/ExcelR Assignment files/Cars.csv")
df20
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
#The CDF is the probability that random variable values less than or equal to x whereas the PDF is a probability that a random variable, say X, will take a value exactly equal to x.
#by default they give us left side value
1-norm.cdf(38,loc=34.422076,scale=9.131445)
# Out:
# 0.34759394041453007

# %%
norm.cdf(40,loc=34.422076,scale=9.131445)
# Out:
# 0.7293498604157946

# %%
norm.cdf(50,loc=34.422076,scale=9.131445)- norm.cdf(20,loc=34.422076,scale=9.131445)
# Out:
# 0.8988689076273199

# %% [markdown]
# # Q21_a

# %%
sns.distplot(df20["MPG"], kde=True, color = "brown" )
#kernal density estimation
# Out:
# C:\Users\Shivani Bhavsar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MPG', ylabel='Density'>

# %%
stats.kstest(df20["MPG"],'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %% [markdown]
# # Q21_b

# %%
df21 = pd.read_csv("C:/Users/Shivani Bhavsar/OneDrive/Documents/ExcelR Assignment files/wc-at.csv")
df21
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
sns.distplot(df21["AT"], kde=True, color = "green" )
# Out:
# C:\Users\Shivani Bhavsar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AT', ylabel='Density'>

# %%
stats.kstest(df21["AT"],'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %% [markdown]
# # Q22

# %%
df22= pd.read_csv("C:/Users/Shivani Bhavsar/OneDrive/Documents/ExcelR Assignment files/Computer_Data.csv", index_col=0)
df22
# Out:
#       price  speed    hd  ram  screen   cd multi premium  ads  trend
# 1      1499     25    80    4      14   no    no     yes   94      1
# 2      1795     33    85    2      14   no    no     yes   94      1
# 3      1595     25   170    4      15   no    no     yes   94      1
# 4      1849     25   170    8      14   no    no      no   94      1
# 5      3295     33   340   16      14   no    no     yes   94      1
# ...     ...    ...   ...  ...     ...  ...   ...     ...  ...    ...
# 6255   1690    100   528    8      15   no    no     yes   39     35
# 6256   2223     66   850   16      15  yes   yes     yes   39     35
# 6257   2654    100  1200   24      15  yes    no     yes   39     35
# 6258   2195    100   850   16      15  yes    no     yes   39     35
# 6259   2490    100   850   16      17  yes    no     yes   39     35
#
# [6259 rows x 10 columns]

# %%
#price
norm.interval(0.90,loc = 2219.576610,scale = 580.803956)
# Out:
# (1264.2391164256364, 3174.9141035743633)

# %%
#speed
norm.interval(0.94,loc = 52.011024,scale = 21.157735)
# Out:
# (12.217691249041998, 91.804356750958)

# %%
#hd
norm.interval(0.60,loc = 416.601694,scale = 258.548445)
# Out:
# (199.00183278074124, 634.2015552192588)
